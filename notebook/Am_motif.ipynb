# %%
import numpy as np
import modisco
from importlib import reload
from collections import OrderedDict

import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = '../results/Am/'

task_to_scores = OrderedDict()
task_to_hyp_scores = OrderedDict()
task_to_scores['Am'] = np.load(data_dir + 'shuffle_task_to_scores.npy', allow_pickle=True)
task_to_hyp_scores['Am'] = np.load(data_dir + 'shuffle_task_to_hyp_scores.npy', allow_pickle=True)
onehot_data = np.load(data_dir + 'shuffle_onehot_data.npy', allow_pickle=True)

# %%
import modisco.visualization
from modisco.visualization import viz_sequence

viz_sequence.plot_weights(task_to_scores['Am'][1], subticks_frequency=5)
viz_sequence.plot_weights(task_to_hyp_scores['Am'][1], subticks_frequency=5)
viz_sequence.plot_weights(onehot_data[1], subticks_frequency=5)

# %%
null_per_pos_scores = modisco.coordproducers.LaplaceNullDist(num_to_samp=5000)
tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                    #Slight modifications from the default settings
                    sliding_window_size=9,
                    flank_size=4,
                    target_seqlet_fdr=0.01,
                    seqlets_to_patterns_factory=
                     modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                        trim_to_window_size=9,
                        initial_flank_to_add=4,
                        kmer_len=8, num_gaps=3,
                        num_mismatches=2,
                        final_min_cluster_size=30)
                )(
                 task_names=["Am"],
                 contrib_scores=task_to_scores,
                 hypothetical_contribs=task_to_hyp_scores,
                 one_hot=onehot_data,
                 null_per_pos_scores = null_per_pos_scores,
                 revcomp=False
)
# Out:
# TF-MoDISco is using the TensorFlow backend.
# WARNING:tensorflow:From /home/daiyun/anaconda3/envs/disco/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# MEMORY 0.362717184
# On task Am
# Computing windowed sums on original
# Generating null dist
# peak(mu)= -0.0025924678528681396
# Computing threshold
# For increasing = True , the minimum IR precision was 0.3639168479085529 occurring at 1.7508864402770996e-06 implying a frac_neg of 0.5721215012722645
# To be conservative, adjusted frac neg is 0.95
# For increasing = False , the minimum IR precision was 0.3604269830278166 occurring at -2.9206275939941406e-06 implying a frac_neg of 0.5635431349717064
# To be conservative, adjusted frac neg is 0.95
# Thresholds from null dist were -0.2643205001950264  and  0.4563673511147499 with frac passing 0.024513121287314837
# Passing windows frac was 0.024513121287314837 , which is below  0.03 ; adjusting
# Final raw thresholds are -0.4166893635690213  and  0.4166893635690213
# Final transformed thresholds are -0.9699977441912926  and  0.9699977441912926
# Got 151 coords
# After resolving overlaps, got 151 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.9698977441912926
# MEMORY 0.373895168
# 151 identified in total
# 1 activity patterns with support >= 100 out of 2 possible patterns
# Metacluster sizes:  [150]
# Idx to activities:  {0: '1'}
# MEMORY 0.373895168
# On metacluster 0
# Metacluster size 150
# Relevant tasks:  ('Am',)
# Relevant signs:  (1,)
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 150
# (Round 1) Computing coarse affmat
# MEMORY 0.420237312
# Beginning embedding computation
# MEMORY 0.420237312
# Computing embeddings
# MAKING A SESSION
# 2021-09-20 20:57:41.020770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-09-20 20:57:41.061514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-20 20:57:41.062444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: TITAN RTX major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:08:00.0
# 2021-09-20 20:57:41.062676: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudart.so.10.0'; dlerror: libcudart.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-10.1/lib64
# 2021-09-20 20:57:41.062808: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10.0'; dlerror: libcublas.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-10.1/lib64
# 2021-09-20 20:57:41.062936: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcufft.so.10.0'; dlerror: libcufft.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-10.1/lib64
# 2021-09-20 20:57:41.063063: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcurand.so.10.0'; dlerror: libcurand.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-10.1/lib64
# 2021-09-20 20:57:41.063192: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusolver.so.10.0'; dlerror: libcusolver.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-10.1/lib64
# 2021-09-20 20:57:41.063317: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusparse.so.10.0'; dlerror: libcusparse.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-10.1/lib64
# 2021-09-20 20:57:41.065302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-09-20 20:57:41.065317: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1641] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-09-20 20:57:41.065984: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-09-20 20:57:41.070007: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3692550000 Hz
# 2021-09-20 20:57:41.070379: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561d75bfb570 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-09-20 20:57:41.070396: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-09-20 20:57:41.155590: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-20 20:57:41.156613: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561d75c9e060 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-09-20 20:57:41.156638: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): TITAN RTX, Compute Capability 7.5
# 2021-09-20 20:57:41.156778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-20 20:57:41.156797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]
# Finished embedding computation in 0.71 s
# MEMORY 0.713887744
# Starting affinity matrix computations
# MEMORY 0.713887744
# Batching in slices of size 150
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 30.03it/s]
# Finished affinity matrix computations in 0.05 s
# MEMORY 0.714604544
# (Round 1) Computed coarse affmat
# MEMORY 0.680194048
# (Round 1) Computing affinity matrix on nearest neighbors
# MEMORY 0.680194048
# Launching nearest neighbors affmat calculation job
# MEMORY 0.680194048
# Parallel runs completed
# MEMORY 0.683012096
# Job completed in: 0.38 s
# MEMORY 0.683012096
# (Round 1) Computed affinity matrix on nearest neighbors in 0.46 s
# MEMORY 0.683012096
# Filtered down to 148 of 150
# (Round 1) Retained 148 rows out of 150 after filtering
# MEMORY 0.683012096
# (Round 1) Computing density adapted affmat
# MEMORY 0.683012096
# Symmetrizing nearest neighbors
# Computing betas for density adaptation
# Computing normalizing denominators
# (Round 1) Computing clustering
# MEMORY 0.684843008
# Beginning preprocessing + Leiden
# Affmat shape: 148
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Quality: 0.012594166926771498
# Quality: 0.01288833254886811
# Got 4 clusters after round 1
# Counts:
# {0: 53, 1: 45, 3: 12, 2: 38}
# MEMORY 0.68552704
# (Round 1) Aggregating seqlets in each cluster
# MEMORY 0.68552704
# Aggregating for cluster 0 with 53 seqlets
# MEMORY 0.68552704
# Trimming eliminated 0 seqlets out of 53
# Aggregating for cluster 1 with 45 seqlets
# MEMORY 0.685531136
# Trimming eliminated 0 seqlets out of 45
# Aggregating for cluster 2 with 38 seqlets
# MEMORY 0.685531136
# Trimming eliminated 0 seqlets out of 38
# Aggregating for cluster 3 with 12 seqlets
# MEMORY 0.685531136
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    2.2s finished
# Trimming eliminated 0 seqlets out of 12
# (Round 2) num seqlets: 148
# (Round 2) Computing coarse affmat
# MEMORY 0.685010944
# Beginning embedding computation
# MEMORY 0.685010944
# Computing embeddings
# Finished embedding computation in 0.44 s
# MEMORY 0.766304256
# Starting affinity matrix computations
# MEMORY 0.766304256
# Batching in slices of size 148
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 28.43it/s]
# Finished affinity matrix computations in 0.06 s
# MEMORY 0.766734336
# (Round 2) Computed coarse affmat
# MEMORY 0.732782592
# (Round 2) Computing affinity matrix on nearest neighbors
# MEMORY 0.732782592
# Launching nearest neighbors affmat calculation job
# MEMORY 0.732782592
# Parallel runs completed
# MEMORY 0.733806592
# Job completed in: 0.38 s
# MEMORY 0.733806592
# (Round 2) Computed affinity matrix on nearest neighbors in 0.46 s
# MEMORY 0.733806592
# Not applying filtering for rounds above first round
# MEMORY 0.733806592
# (Round 2) Computing density adapted affmat
# MEMORY 0.733806592
# Symmetrizing nearest neighbors
# Computing betas for density adaptation
# Computing normalizing denominators
# (Round 2) Computing clustering
# MEMORY 0.73541632
# Beginning preprocessing + Leiden
# Affmat shape: 148
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Quality: 0.012658223211813998
# Quality: 0.012677230077862804
# Quality: 0.01268542408358234
# Got 4 clusters after round 2
# Counts:
# {1: 40, 2: 34, 0: 43, 3: 31}
# MEMORY 0.73541632
# (Round 2) Aggregating seqlets in each cluster
# MEMORY 0.73541632
# Aggregating for cluster 0 with 43 seqlets
# MEMORY 0.73541632
# Trimming eliminated 0 seqlets out of 43
# Aggregating for cluster 1 with 40 seqlets
# MEMORY 0.73541632
# Trimming eliminated 0 seqlets out of 40
# Aggregating for cluster 2 with 34 seqlets
# MEMORY 0.73541632
# Trimming eliminated 0 seqlets out of 34
# Aggregating for cluster 3 with 31 seqlets
# MEMORY 0.73541632
# Trimming eliminated 0 seqlets out of 31
# Got 4 clusters
# Splitting into subclusters...
# MEMORY 0.73541632
# Inspecting pattern 0 for spurious merging
# Inspecting pattern 1 for spurious merging
# Inspecting pattern 2 for spurious merging
# Inspecting pattern 3 for spurious merging
# Merging on 4 clusters
# MEMORY 0.73541632
# On merging iteration 1
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    2.3s finished
# Numbers for each pattern pre-subsample: [43, 40, 34, 31]
# Numbers after subsampling: [43, 40, 34, 31]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.14430594444274902 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.13421082496643066 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.1528925895690918 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.12944674491882324 s
# Cluster sizes
# [43 40 34 31]
# Cross-contamination matrix:
# [[1.   0.93 0.65 0.81]
#  [0.38 1.   0.44 0.48]
#  [0.61 0.94 1.   0.85]
#  [0.45 0.67 0.54 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.81 0.81 0.82]
#  [0.81 1.   0.84 0.84]
#  [0.81 0.84 1.   0.91]
#  [0.82 0.84 0.91 1.  ]]
# Collapsing 2 & 3 with crosscontam 0.5358507405513313 and sim 0.9135568938677127
# Trimming eliminated 0 seqlets out of 65
# Unmerged patterns remapping: OrderedDict([(0, 1), (1, 2)])
# Time spent on merging iteration: 0.17163562774658203
# On merging iteration 2
# Numbers for each pattern pre-subsample: [65, 43, 40]
# Numbers after subsampling: [65, 43, 40]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.1286921501159668 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.05565023422241211 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.04887080192565918 s
# Cluster sizes
# [65 43 40]
# Cross-contamination matrix:
# [[1.   0.7  0.99]
#  [0.73 1.   0.93]
#  [0.46 0.38 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.84 0.86]
#  [0.84 1.   0.81]
#  [0.86 0.81 1.  ]]
# Got 3 patterns after merging
# MEMORY 0.73562112
# Performing filtering
# MEMORY 0.73562112
# Got 3 patterns after filtering
# MEMORY 0.73562112
# Total time taken is 9.55s
# MEMORY 0.73562112
# Applying subclustering to the final motifs
# On pattern 0
# [t-SNE] Computing 64 nearest neighbors...
# [t-SNE] Indexed 65 samples in 0.001s...
# [t-SNE] Computed neighbors for 65 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 65 / 65
# [t-SNE] Mean sigma: 0.579757
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = 51.4588547, gradient norm = 0.4313185 (50 iterations in 0.016s)
# [t-SNE] Iteration 100: error = 47.4924278, gradient norm = 0.6226667 (50 iterations in 0.010s)
# [t-SNE] Iteration 150: error = 46.0823059, gradient norm = 0.4529978 (50 iterations in 0.010s)
# [t-SNE] Iteration 200: error = 48.1411400, gradient norm = 0.5936077 (50 iterations in 0.075s)
# [t-SNE] Iteration 250: error = 46.5930367, gradient norm = 0.4922261 (50 iterations in 0.010s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 46.593037
# [t-SNE] Iteration 300: error = 0.7659496, gradient norm = 0.0014300 (50 iterations in 0.010s)
# [t-SNE] Iteration 350: error = 0.6702561, gradient norm = 0.0010843 (50 iterations in 0.010s)
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  65 out of  65 | elapsed:    0.0s finished
# [t-SNE] Iteration 400: error = 0.6152385, gradient norm = 0.0009267 (50 iterations in 0.036s)
# [t-SNE] Iteration 450: error = 0.5584403, gradient norm = 0.0007348 (50 iterations in 0.011s)
# [t-SNE] Iteration 500: error = 0.5147008, gradient norm = 0.0008365 (50 iterations in 0.010s)
# [t-SNE] Iteration 550: error = 0.4893244, gradient norm = 0.0005555 (50 iterations in 0.010s)
# [t-SNE] Iteration 600: error = 0.4564509, gradient norm = 0.0004869 (50 iterations in 0.010s)
# [t-SNE] Iteration 650: error = 0.4464424, gradient norm = 0.0002621 (50 iterations in 0.010s)
# [t-SNE] Iteration 700: error = 0.4377990, gradient norm = 0.0002475 (50 iterations in 0.010s)
# [t-SNE] Iteration 750: error = 0.4259185, gradient norm = 0.0005270 (50 iterations in 0.010s)
# [t-SNE] Iteration 800: error = 0.4137647, gradient norm = 0.0006795 (50 iterations in 0.010s)
# [t-SNE] Iteration 850: error = 0.7216074, gradient norm = 0.0626704 (50 iterations in 0.010s)
# [t-SNE] Iteration 900: error = 0.8273126, gradient norm = 0.0010692 (50 iterations in 0.010s)
# [t-SNE] Iteration 950: error = 0.7233613, gradient norm = 0.0004620 (50 iterations in 0.010s)
# [t-SNE] Iteration 1000: error = 0.6857124, gradient norm = 0.0002758 (50 iterations in 0.010s)
# [t-SNE] KL divergence after 1000 iterations: 0.685712
# [t-SNE] Computed conditional probabilities for sample 65 / 65
# [t-SNE] Mean sigma: 0.579757
# Beginning preprocessing + Leiden
# Affmat shape: 65
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Quality: 0.12385923310294172
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    2.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  36 out of  43 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  43 out of  43 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 22, 1: 22, 2: 21})
# On pattern 1
# [t-SNE] Computing 42 nearest neighbors...
# [t-SNE] Indexed 43 samples in 0.001s...
# [t-SNE] Computed neighbors for 43 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 43 / 43
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 45.1561432, gradient norm = 0.4550527 (50 iterations in 0.011s)
# [t-SNE] Iteration 100: error = 49.0812683, gradient norm = 0.4520793 (50 iterations in 0.008s)
# [t-SNE] Iteration 150: error = 45.4180183, gradient norm = 0.5224083 (50 iterations in 0.009s)
# [t-SNE] Iteration 200: error = 48.9434700, gradient norm = 0.5377184 (50 iterations in 0.008s)
# [t-SNE] Iteration 250: error = 45.3842354, gradient norm = 0.8476522 (50 iterations in 0.009s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 45.384235
# [t-SNE] Iteration 300: error = 0.6132307, gradient norm = 0.0008143 (50 iterations in 0.008s)
# [t-SNE] Iteration 350: error = 0.5861698, gradient norm = 0.0001547 (50 iterations in 0.008s)
# [t-SNE] Iteration 400: error = 0.5822758, gradient norm = 0.0000381 (50 iterations in 0.008s)
# [t-SNE] Iteration 450: error = 0.5818885, gradient norm = 0.0000243 (50 iterations in 0.008s)
# [t-SNE] Iteration 500: error = 0.5821879, gradient norm = 0.0000205 (50 iterations in 0.008s)
# [t-SNE] Iteration 550: error = 0.5813314, gradient norm = 0.0000383 (50 iterations in 0.008s)
# [t-SNE] Iteration 600: error = 0.5812856, gradient norm = 0.0000217 (50 iterations in 0.008s)
# [t-SNE] Iteration 650: error = 0.5810172, gradient norm = 0.0000169 (50 iterations in 0.008s)
# [t-SNE] Iteration 700: error = 0.5808842, gradient norm = 0.0000173 (50 iterations in 0.008s)
# [t-SNE] Iteration 750: error = 0.5808838, gradient norm = 0.0000178 (50 iterations in 0.008s)
# [t-SNE] Iteration 800: error = 0.5808980, gradient norm = 0.0000177 (50 iterations in 0.008s)
# [t-SNE] Iteration 850: error = 0.5807925, gradient norm = 0.0000184 (50 iterations in 0.008s)
# [t-SNE] Iteration 900: error = 0.5805256, gradient norm = 0.0000243 (50 iterations in 0.008s)
# [t-SNE] Iteration 950: error = 0.5800563, gradient norm = 0.0001154 (50 iterations in 0.039s)
# [t-SNE] Iteration 1000: error = 0.5796042, gradient norm = 0.0000575 (50 iterations in 0.011s)
# [t-SNE] KL divergence after 1000 iterations: 0.579604
# [t-SNE] Computed conditional probabilities for sample 43 / 43
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 43
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Quality: -1.9084733793306774e-13
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    2.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  40 out of  40 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 43})
# On pattern 2
# [t-SNE] Computing 39 nearest neighbors...
# [t-SNE] Indexed 40 samples in 0.001s...
# [t-SNE] Computed neighbors for 40 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 40 / 40
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 51.1586914, gradient norm = 0.3567340 (50 iterations in 0.011s)
# [t-SNE] Iteration 100: error = 44.8546906, gradient norm = 0.2473018 (50 iterations in 0.008s)
# [t-SNE] Iteration 150: error = 46.2767105, gradient norm = 0.4203950 (50 iterations in 0.008s)
# [t-SNE] Iteration 200: error = 41.6234093, gradient norm = 0.6102985 (50 iterations in 0.008s)
# [t-SNE] Iteration 250: error = 42.3033676, gradient norm = 0.3594796 (50 iterations in 0.008s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 42.303368
# [t-SNE] Iteration 300: error = 0.6444248, gradient norm = 0.0008340 (50 iterations in 0.008s)
# [t-SNE] Iteration 350: error = 0.5754110, gradient norm = 0.0002782 (50 iterations in 0.008s)
# [t-SNE] Iteration 400: error = 0.5674162, gradient norm = 0.0000647 (50 iterations in 0.008s)
# [t-SNE] Iteration 450: error = 0.5667813, gradient norm = 0.0000354 (50 iterations in 0.008s)
# [t-SNE] Iteration 500: error = 0.5654131, gradient norm = 0.0000310 (50 iterations in 0.008s)
# [t-SNE] Iteration 550: error = 0.5651364, gradient norm = 0.0000168 (50 iterations in 0.008s)
# [t-SNE] Iteration 600: error = 0.5650481, gradient norm = 0.0000149 (50 iterations in 0.008s)
# [t-SNE] Iteration 650: error = 0.5650932, gradient norm = 0.0000149 (50 iterations in 0.008s)
# [t-SNE] Iteration 700: error = 0.5646796, gradient norm = 0.0000198 (50 iterations in 0.008s)
# [t-SNE] Iteration 750: error = 0.5648082, gradient norm = 0.0000187 (50 iterations in 0.008s)
# [t-SNE] Iteration 800: error = 0.5646934, gradient norm = 0.0000211 (50 iterations in 0.008s)
# [t-SNE] Iteration 850: error = 0.5645987, gradient norm = 0.0000314 (50 iterations in 0.008s)
# [t-SNE] Iteration 900: error = 0.5636302, gradient norm = 0.0000612 (50 iterations in 0.008s)
# [t-SNE] Iteration 950: error = 0.5621333, gradient norm = 0.0001165 (50 iterations in 0.008s)
# [t-SNE] Iteration 1000: error = 0.5478539, gradient norm = 0.0034651 (50 iterations in 0.031s)
# [t-SNE] KL divergence after 1000 iterations: 0.547854
# [t-SNE] Computed conditional probabilities for sample 40 / 40
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 40
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Quality: 2.2204460492503205e-16
# Got subclusters: Counter({0: 40})
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    2.0s finished

# %%
import h5py
import modisco.util
reload(modisco.util)
![[ -e ../results/Am/results.hdf5 ]] && rm ../results/Am/results.hdf5
grp = h5py.File(data_dir + "results.hdf5", "w")
tfmodisco_results.save_hdf5(grp)
grp.close()

# %%
from collections import Counter
from modisco.visualization import viz_sequence
reload(viz_sequence)
from matplotlib import pyplot as plt

import modisco.affinitymat.core
reload(modisco.affinitymat.core)
import modisco.cluster.phenograph.core
reload(modisco.cluster.phenograph.core)
import modisco.cluster.phenograph.cluster
reload(modisco.cluster.phenograph.cluster)
import modisco.cluster.core
reload(modisco.cluster.core)
import modisco.aggregator
reload(modisco.aggregator)

hdf5_results = h5py.File(data_dir + "results.hdf5","r")

print("Metaclusters heatmap")
import seaborn as sns
activity_patterns = np.array(hdf5_results['metaclustering_results']['attribute_vectors'])[
                    np.array(
        [x[0] for x in sorted(
                enumerate(hdf5_results['metaclustering_results']['metacluster_indices']),
               key=lambda x: x[1])])]
sns.heatmap(activity_patterns, center=0)
plt.show()

metacluster_names = [
    x.decode("utf-8") for x in 
    list(hdf5_results["metaclustering_results"]
         ["all_metacluster_names"][:])]

all_patterns = []
background = np.array([0.272, 0.2125, 0.2315, 0.284])

for metacluster_name in metacluster_names:
    print(metacluster_name)
    metacluster_grp = (hdf5_results["metacluster_idx_to_submetacluster_results"]
                                   [metacluster_name])
    print("activity pattern:",metacluster_grp["activity_pattern"][:])
    all_pattern_names = [x.decode("utf-8") for x in 
                         list(metacluster_grp["seqlets_to_patterns_result"]
                                             ["patterns"]["all_pattern_names"][:])]
    if (len(all_pattern_names)==0):
        print("No motifs found for this activity pattern")
    for pattern_name in all_pattern_names:
        print(metacluster_name, pattern_name)
        all_patterns.append((metacluster_name, pattern_name))
        pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
        print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
        
        print("onehot, fwd and rev:")
        viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["fwd"]),
                                                        background=background)) 
        
hdf5_results.close()
# Out:
# Metaclusters heatmap
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_0
# total seqlets: 65
# onehot, fwd and rev:
# metacluster_0 pattern_1
# total seqlets: 43
# onehot, fwd and rev:
# metacluster_0 pattern_2
# total seqlets: 40
# onehot, fwd and rev:

# %%
from modisco.tfmodisco_workflow import workflow

track_set = modisco.tfmodisco_workflow.workflow.prep_track_set(
                task_names=['Am'],
                contrib_scores=task_to_scores,
                hypothetical_contribs=task_to_hyp_scores,
                one_hot=onehot_data)

grp = h5py.File(data_dir + "results.hdf5","r")
loaded_tfmodisco_results =\
    workflow.TfModiscoResults.from_hdf5(grp, track_set=track_set)
grp.close()

# %%
untrimmed_gata_pattern = (
    loaded_tfmodisco_results
    .metacluster_idx_to_submetacluster_results["metacluster_0"]
    .seqlets_to_patterns_result.patterns[1])
print("Untrimmed Gata - sequence (scaled by information content)")
viz_sequence.plot_weights(viz_sequence.ic_scale(untrimmed_gata_pattern["sequence"].fwd, background=background))
print("Untrimmed Gata - task 0 hypothetical scores")
viz_sequence.plot_weights(untrimmed_gata_pattern["Am_hypothetical_contribs"].fwd)
trimmed_gata = untrimmed_gata_pattern.trim_by_ic(ppm_track_name="sequence",
                                                 background=background,
                                                 threshold=0.3)
print("IC-trimmed Gata - sequence (scaled by information content)")
viz_sequence.plot_weights(viz_sequence.ic_scale(trimmed_gata["sequence"].fwd, background=background))
# Out:
# Untrimmed Gata - sequence (scaled by information content)
# Untrimmed Gata - task 0 hypothetical scores
# IC-trimmed Gata - sequence (scaled by information content)

# %%
np.save(data_dir + 'Am_motif3.npy', viz_sequence.ic_scale(trimmed_gata["sequence"].fwd, background=background))
